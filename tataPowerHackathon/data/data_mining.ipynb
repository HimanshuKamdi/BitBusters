# %%
import requests
import json

# %%
# %cd /content/drive/MyDrive/MS Hackathon
# Out:
# /content/drive/MyDrive/MS Hackathon

# %%
API_KEY = "AIzaSyCoRbpSkOMQvnDrGLNEQmITHarqpJKJY4I"
base_url = "https://www.googleapis.com/youtube/v3/"

# %%
topics=["Renewable Energy","Sustainable Energy","Renewable and  Sustainable Energy","Solar Energy","Wind Energy","Biogas Energy","Conservable Resources","Hydro Power","Clean Energy","Green Energy"]

# %%
def topicwise_stats(topic,idx):
  params = {
    "key": API_KEY,
    "part": "snippet",
    "q": topic,
    "type": "video",
    "maxResults": 50
  }
  endpoint = "search"
  response = requests.get(base_url + endpoint, params=params)
  data = response.json()

  video_stats_list = []


  for item in data['items']:
    video_id = item['id']['videoId']
    video_stats_params = {
        "key": API_KEY,
        "part": "snippet,statistics",
        "id": video_id
    }
    video_stats_response = requests.get(base_url + "videos", params=video_stats_params)
    video_stats_data = video_stats_response.json()
    video_stats_list.append(video_stats_data)

  sorted_data=sorted([item for item in video_stats_list if int(item['items'][0]['statistics']['viewCount']) > 10000],key=lambda x: int(x['items'][0]['statistics']['viewCount']), reverse=True)

  with open(f"{idx}.json", "w") as output_file:
    json.dump(sorted_data, output_file, indent=4)

# %%
for i in range(len(topics)):
  topicwise_stats(topics[i],i)

# %%
def get_comments(video_id):
  endpoint = "commentThreads"

  params = {
      "key": API_KEY,
      "part": "snippet",
      "video_id":video_id,
      "maxResults":50,
  }

  response = requests.get(base_url + endpoint, params=params)
  data = response.json()
  return(data)

# %%
count=0

for i in range(len(topics)):

  print(f"Processing topic: {topics[count]}")
  with open(f"{i}.json", "r") as file:
    id_to_comment={}
    data = json.load(file)
    for idx in range(len(data)):
      key=(data[idx]["items"][0]["id"])
      id_to_comment[key]=get_comments(key)


    with open(f"{i}_comments.json", "w") as file:
      json.dump(id_to_comment, file, indent=4)
    count+=1
# Out:
# Processing topic: Renewable Energy
# Processing topic: Sustainable Energy
# Processing topic: Renewable and  Sustainable Energy
# Processing topic: Solar Energy
# Processing topic: Wind Energy
# Processing topic: Biogas Energy
# Processing topic: Conservable Resources
# Processing topic: Hydro Power
# Processing topic: Clean Energy
# Processing topic: Green Energy

# %%
import requests

def get_topics(api_key, channel_id):
    base_url = "https://www.googleapis.com/youtube/v3/"
    comment_params = {
        "key": api_key,
        "part": "snippet",
        "channelId": channel_id,
        "maxResults": 100,  # Adjust the max results as needed, maximum is 100
        "textFormat": "plainText"  # Request plain text for easier processing
    }
    comment_endpoint = "commentThreads"
    comment_response = requests.get(base_url + comment_endpoint, params=comment_params)
    comment_data = comment_response.json()
    print(comment_data)
    return
    topic_tags = []
    for item in comment_data["items"]:
        comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
        # Implement your logic to extract topic tags from comments here
        # For example, you can use natural language processing (NLP) techniques or regular expressions
        # Append the extracted topic tags to the topic_tags list

    return topic_tags

# %%
get_commenter_comments(API_KEY,'UCAZ4uv07_hnrKL1kvux82XQ')
# Out:
# {'error': {'code': 404, 'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'errors': [{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]}}
